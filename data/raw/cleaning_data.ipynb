# %%
import pandas as pd 
df=pd.read_csv('02_nav_history.csv')
df.head()
# Out:
#    amfi_code        date      nav
# 0     119551  2022-01-03  54.3856
# 1     119551  2022-01-04  54.3474
# 2     119551  2022-01-05  54.6869
# 3     119551  2022-01-06  55.4550
# 4     119551  2022-01-07  55.3692

# %%
import os 
print(os.getcwd())
# Out:
# c:\Users\h7743\Desktop\mutual funds analystics\data\raw

# %%
df.dtypes
# Out:
# amfi_code      int64
# date          object
# nav          float64
# dtype: object

# %%
df['date']=pd.to_datetime(df['date'], format='%Y-%m-%d')
df['date'].head()
# Out:
# 0   2022-01-03
# 1   2022-01-04
# 2   2022-01-05
# 3   2022-01-06
# 4   2022-01-07
# Name: date, dtype: datetime64[ns]

# %%
df.dtypes
# Out:
# amfi_code             int64
# date         datetime64[ns]
# nav                 float64
# dtype: object

# %%
df['date']=df['date'].sort_values()

# %%
df.head()
# Out:
#    amfi_code       date      nav
# 0     119551 2022-01-03  54.3856
# 1     119551 2022-01-04  54.3474
# 2     119551 2022-01-05  54.6869
# 3     119551 2022-01-06  55.4550
# 4     119551 2022-01-07  55.3692

# %%
df[df['nav'].isnull()]
# Out:
# Empty DataFrame
# Columns: [amfi_code, date, nav]
# Index: []

# %%
df['nav'].unique()
# Out:
# array([ 54.3856,  54.3474,  54.6869, ..., 288.8007, 280.6873, 279.7511],
#       shape=(45594,))

# %%
len(df['nav'].isnull())
# Out:
# 46000

# %%
len(df['nav'])
# Out:
# 46000

# %%
df[df['nav']=='']
# Out:
# Empty DataFrame
# Columns: [amfi_code, date, nav]
# Index: []

# %%
#NAV column inspected.
#No null values found.
#No blank values found.Forward fill not required because NAV history is complete.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df[df['nav']<=0]
# Out:
# Empty DataFrame
# Columns: [amfi_code, date, nav]
# Index: []

# %%
df['nav'].min()
# Out:
# np.float64(26.1366)

# %%
df.to_csv('../processed/nav_history_clean.csv', index=False)

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# c:\Users\h7743\Desktop\mutual funds analystics\data\raw
# ['01_fund_master.csv', '02_nav_history.csv', '03_aum_by_fund_house.csv', '04_monthly_sip_inflows.csv', '05_category_inflows.csv', '06_industry_folio_count.csv', '07_scheme_performance.csv', '08_investor_transactions.csv', '09_portfolio_holdings.csv', '10_benchmark_indices.csv', 'api_data.csv', 'api_data.ipynb', 'cleaning_data.ipynb', 'icici_bluechip.csv', 'inspection.ipynb', 'kotak_bluechip.csv', 'm_api_data.py', 'nippon_largecap.csv', 'sbi_bluechip.csv']

# %%
d=pd.read_csv('08_investor_transactions.csv')
d.head()
# Out:
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 1   INV002952       2024-01-01     148567       Redemption      392882
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 4   INV004691       2024-01-01     119094          Lumpsum        8682
#
#          state       city city_tier age_group  gender  annual_income_lakh  \
# 0    Telangana  Hyderabad       T30       56+  Female                77.1
# 1       Punjab   Amritsar       B30     18-25    Male                 7.1
# 2      Haryana  Faridabad       B30     36-45    Male                47.2
# 3  Maharashtra     Mumbai       T30     36-45  Female                54.4
# 4        Delhi      Noida       T30     26-35    Male                14.5
#
#   payment_mode kyc_status
# 0          UPI   Verified
# 1       Cheque   Verified
# ...

# %%
d.dtypes
# Out:
# investor_id            object
# transaction_date       object
# amfi_code               int64
# transaction_type       object
# amount_inr              int64
# state                  object
# city                   object
# city_tier              object
# age_group              object
# gender                 object
# annual_income_lakh    float64
# payment_mode           object
# kyc_status             object
# dtype: object

# %%
d['transaction_type'].unique()
#no unstandard transaction types found.
# Out:
# array(['SIP', 'Redemption', 'Lumpsum'], dtype=object)

# %%
d['amount_inr'].min()
# Out:
# np.int64(400)

# %%
d['amount_inr'].max()
# Out:
# np.int64(597498)

# %%
d.head()
# Out:
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 1   INV002952       2024-01-01     148567       Redemption      392882
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 4   INV004691       2024-01-01     119094          Lumpsum        8682
#
#          state       city city_tier age_group  gender  annual_income_lakh  \
# 0    Telangana  Hyderabad       T30       56+  Female                77.1
# 1       Punjab   Amritsar       B30     18-25    Male                 7.1
# 2      Haryana  Faridabad       B30     36-45    Male                47.2
# 3  Maharashtra     Mumbai       T30     36-45  Female                54.4
# 4        Delhi      Noida       T30     26-35    Male                14.5
#
#   payment_mode kyc_status
# 0          UPI   Verified
# 1       Cheque   Verified
# ...

# %%
d.dtypes
# Out:
# investor_id            object
# transaction_date       object
# amfi_code               int64
# transaction_type       object
# amount_inr              int64
# state                  object
# city                   object
# city_tier              object
# age_group              object
# gender                 object
# annual_income_lakh    float64
# payment_mode           object
# kyc_status             object
# dtype: object

# %%
d.dtypes
# Out:
# investor_id            object
# transaction_date       object
# amfi_code               int64
# transaction_type       object
# amount_inr              int64
# state                  object
# city                   object
# city_tier              object
# age_group              object
# gender                 object
# annual_income_lakh    float64
# payment_mode           object
# kyc_status             object
# dtype: object

# %%
d['transaction_date']
# Out:
# 0        2024-01-01
# 1        2024-01-01
# 2        2024-01-01
# 3        2024-01-01
# 4        2024-01-01
#             ...
# 32773    2025-05-30
# 32774    2025-05-30
# 32775    2025-05-30
# 32776    2025-05-30
# 32777    2025-05-30
# Name: transaction_date, Length: 32778, dtype: object

# %%
d['transaction_date']=pd.to_datetime(d['transaction_date'], format='%Y-%m-%d')

# %%
d.dtypes
# Out:
# investor_id                   object
# transaction_date      datetime64[ns]
# amfi_code                      int64
# transaction_type              object
# amount_inr                     int64
# state                         object
# city                          object
# city_tier                     object
# age_group                     object
# gender                        object
# annual_income_lakh           float64
# payment_mode                  object
# kyc_status                    object
# dtype: object

# %%
d.head()
# Out:
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 1   INV002952       2024-01-01     148567       Redemption      392882
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 4   INV004691       2024-01-01     119094          Lumpsum        8682
#
#          state       city city_tier age_group  gender  annual_income_lakh  \
# 0    Telangana  Hyderabad       T30       56+  Female                77.1
# 1       Punjab   Amritsar       B30     18-25    Male                 7.1
# 2      Haryana  Faridabad       B30     36-45    Male                47.2
# 3  Maharashtra     Mumbai       T30     36-45  Female                54.4
# 4        Delhi      Noida       T30     26-35    Male                14.5
#
#   payment_mode kyc_status
# 0          UPI   Verified
# 1       Cheque   Verified
# ...

# %%
d['kyc_status'].unique()
# Out:
# array(['Verified', 'Pending'], dtype=object)

# %%
d.drop_duplicates(inplace=True)

# %%
d.to_csv('../processed/processed_investor_transactions.csv', index=False)

# %%
f=pd.read_csv('07_scheme_performance.csv')
f.head()
# Out:
#    amfi_code                                   scheme_name       fund_house  \
# 0     119551     SBI Bluechip Fund - Regular Plan - Growth  SBI Mutual Fund
# 1     119552      SBI Bluechip Fund - Direct Plan - Growth  SBI Mutual Fund
# 2     119598    SBI Small Cap Fund - Regular Plan - Growth  SBI Mutual Fund
# 3     119599     SBI Small Cap Fund - Direct Plan - Growth  SBI Mutual Fund
# 4     119120  SBI Magnum Gilt Fund - Regular Plan - Growth  SBI Mutual Fund
#
#     category     plan  return_1yr_pct  return_3yr_pct  return_5yr_pct  \
# 0  Large Cap  Regular           12.42           12.36           14.45
# 1  Large Cap   Direct           15.25           11.30           14.23
# 2  Small Cap  Regular           24.56           23.39           20.67
# 3  Small Cap   Direct           20.59           23.14           21.82
# 4       Gilt  Regular            5.34            6.07            5.43
#
#    benchmark_3yr_pct  alpha  beta  sharpe_ratio  sortino_ratio  \
# ...

# %%
f.dtypes
# Out:
# amfi_code               int64
# scheme_name            object
# fund_house             object
# category               object
# plan                   object
# return_1yr_pct        float64
# return_3yr_pct        float64
# return_5yr_pct        float64
# benchmark_3yr_pct     float64
# alpha                 float64
# beta                  float64
# sharpe_ratio          float64
# sortino_ratio         float64
# std_dev_ann_pct       float64
# max_drawdown_pct      float64
# aum_crore               int64
# expense_ratio_pct     float64
# morningstar_rating      int64
# risk_grade             object
# dtype: object

# %%
f['return_1yr_pct'].head()
# Out:
# 0    12.42
# 1    15.25
# 2    24.56
# 3    20.59
# 4     5.34
# Name: return_1yr_pct, dtype: float64

# %%
f['return_1yr_pct'].max()
# Out:
# np.float64(24.93)

# %%
f['return_1yr_pct'].min()
# Out:
# np.float64(4.26)

# %%
f['return_3yr_pct'].min()
# Out:
# np.float64(5.14)

# %%
f['return_3yr_pct'].max()
# Out:
# np.float64(23.39)

# %%
f['return_5yr_pct'].min()
# Out:
# np.float64(5.43)

# %%
f['return_5yr_pct'].max()
# Out:
# np.float64(23.8)

# %%
f['expense_ratio_pct'].min()
# Out:
# np.float64(0.55)

# %%
f['expense_ratio_pct'].max()
# Out:
# np.float64(1.64)

# %%
f.head()
# Out:
#    amfi_code                                   scheme_name       fund_house  \
# 0     119551     SBI Bluechip Fund - Regular Plan - Growth  SBI Mutual Fund
# 1     119552      SBI Bluechip Fund - Direct Plan - Growth  SBI Mutual Fund
# 2     119598    SBI Small Cap Fund - Regular Plan - Growth  SBI Mutual Fund
# 3     119599     SBI Small Cap Fund - Direct Plan - Growth  SBI Mutual Fund
# 4     119120  SBI Magnum Gilt Fund - Regular Plan - Growth  SBI Mutual Fund
#
#     category     plan  return_1yr_pct  return_3yr_pct  return_5yr_pct  \
# 0  Large Cap  Regular           12.42           12.36           14.45
# 1  Large Cap   Direct           15.25           11.30           14.23
# 2  Small Cap  Regular           24.56           23.39           20.67
# 3  Small Cap   Direct           20.59           23.14           21.82
# 4       Gilt  Regular            5.34            6.07            5.43
#
#    benchmark_3yr_pct  alpha  beta  sharpe_ratio  sortino_ratio  \
# ...

# %%
f['fund_house'].unique()
# Out:
# array(['SBI Mutual Fund', 'HDFC Mutual Fund', 'ICICI Prudential MF',
#        'Nippon India MF', 'Kotak Mahindra MF', 'Axis Mutual Fund',
#        'Aditya Birla Sun Life MF', 'UTI Mutual Fund', 'Mirae Asset MF',
#        'DSP Mutual Fund'], dtype=object)

# %%
f['category'].unique()
# Out:
# array(['Large Cap', 'Small Cap', 'Gilt', 'Mid Cap', 'Short Duration',
#        'Value', 'Liquid', 'Index/ETF', 'Flexi Cap', 'Index',
#        'Large & Mid Cap', 'ELSS'], dtype=object)

# %%
f['plan'].unique()
# Out:
# array(['Regular', 'Direct'], dtype=object)

# %%
d.to_csv('../processed/processed_scheme_performance.csv', index=False)
